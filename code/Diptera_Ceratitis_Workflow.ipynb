# %% [markdown]
# # **DATA Retrieval and Cleanup**

# %% [markdown]
# ## **Data Retrival**

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/code/
# source ./process_all_input_files.sh
# bolddata_retrival #-i Diptera -f countries
# #Uncomment the command to download from a list of countries in the file countries
# ls ../data/input/bold_data/diptera_13012021/*-13012021.xml
# Out:
# Input error...
# function usage: bolddata_retrival [-i <Taxonomy>] [-a] [-c <name of country>] [-f <a file with list of countries and named *countries*>]
# ../data/input/bold_data/diptera_13012021/Algeria-13012021.xml
# ../data/input/bold_data/diptera_13012021/Angola-13012021.xml
# ../data/input/bold_data/diptera_13012021/Benin-13012021.xml
# ../data/input/bold_data/diptera_13012021/Botswana-13012021.xml
# ../data/input/bold_data/diptera_13012021/Burkina_Faso-13012021.xml
# ../data/input/bold_data/diptera_13012021/Burundi-13012021.xml
# ../data/input/bold_data/diptera_13012021/Cameroon-13012021.xml
# ../data/input/bold_data/diptera_13012021/Cape_Verde-13012021.xml
# ../data/input/bold_data/diptera_13012021/Central_African_Republic-13012021.xml
# ../data/input/bold_data/diptera_13012021/Chad-13012021.xml
# ../data/input/bold_data/diptera_13012021/Comoros-13012021.xml
# ../data/input/bold_data/diptera_13012021/Cote_dIvoire-13012021.xml
# ...

# %% [markdown]
# ## **Data Extraction - XML to TSV**

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/code/
# source ./process_all_input_files.sh
# boldxml2tsv #../data/input/bold_data/diptera_13012021/*_13012021.xml
# #Uncomment the command to run execute
# ls ../data/input/bold_data/diptera_13012021/*-13012021.tsv
# Out:
# Input error...
# Usage: boldxml2tsv file1.*[file2.* file3.* ...]
#
# 	generating .tsv files from .xml downloads
# ../data/input/bold_data/diptera_13012021/Algeria-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Angola-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Benin-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Botswana-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Burkina_Faso-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Burundi-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Cameroon-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Cape_Verde-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Central_African_Republic-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Comoros-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Cote_dIvoire-13012021.tsv
# ../data/input/bold_data/diptera_13012021/Democratic_republic_of_the_Congo-13012021.tsv
# ...

# %% [markdown]
# ## **Data Sorting**
# This step concatenates all the data (tsv files) into one file and sorts them into Sequence-length dependent groupings:
# 1. diptera_13012021_500to700_data.tsv
# 2. diptera_13012021_650to660_data.tsv
# 3. diptera_13012021_all_data.tsv
# 4. diptera_13012021_NonCOI_data.tsv
# 5. diptera_13012021_Over499_data.tsv
# 6. diptera_13012021_Over700_data.tsv
# 7. diptera_13012021_Under500_data.tsv
#
# This will reduce complexities in downstream steps like Mustiple Sequence Aligment

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/code/
# source ./process_all_input_files.sh
# #awk ' FNR==NR{print $0}; FNR != NR{ if ( $0 ~ /^processid.*$/) {next} else{print $0}}' \
# #../data/input/bold_data/diptera_13012021/*-13012021.tsv >> \
# #../data/input/bold_data/diptera_13012021/diptera-13012021.tsv
# boldtsv_cleanup #diptera-13012021.tsv
# ls ../data/input/bold_data/diptera_13012021/diptera_13012021*
# Out:
# Input error...
# Usage: boldtsv_cleanup file1.*[file2.* file3.* ...]
# ../data/input/bold_data/diptera_13012021/diptera_13012021_500to700_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_500to700_data.tsv
# ../data/input/bold_data/diptera_13012021/diptera_13012021_650to660_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_650to660_data.tsv
# ../data/input/bold_data/diptera_13012021/diptera_13012021_all_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_all_data.genbank_ids
# ../data/input/bold_data/diptera_13012021/diptera_13012021_all_data.tsv
# ../data/input/bold_data/diptera_13012021/diptera_13012021_cleanup
# ../data/input/bold_data/diptera_13012021/diptera_13012021_NonCOI_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_NonCOI_data.tsv
# ../data/input/bold_data/diptera_13012021/diptera_13012021_Over499_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_Over499_data.tsv
# ...

# %% [markdown]
# ## **Data coversion .tsv to .fasta**

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/code/
# source ./process_all_input_files.sh
# boldtsv2fasta #../data/input/bold_data/diptera_13012021/diptera_13012021*_data.tsv
# #Uncomment the command to run execute
# ls ../data/input/bold_data/diptera_13012021/diptera_13012021*.fasta
# #cp ../data/input/bold_data/diptera_13012021/diptera_13012021_* ../data/input/diptera_13012021/
# ls ../data/input/diptera_13012021/diptera_13012021_*
# Out:
# Input error...
# Usage: boldtsv2fasta file1.*[file2.* file3.* ...]
# generating .fasta files from .tsv metadata files
# ../data/input/bold_data/diptera_13012021/diptera_13012021_500to700_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_650to660_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_all_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_NonCOI_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_Over499_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_Over700_data.fasta
# ../data/input/bold_data/diptera_13012021/diptera_13012021_Under500_data.fasta
# ../data/input/diptera_13012021/diptera_13012021_all_data.fasta
# ../data/input/diptera_13012021/diptera_13012021_all_data.genbank_ids
# ../data/input/diptera_13012021/diptera_13012021_all_data.tsv
# ../data/input/diptera_13012021/diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
# ...

# %% [markdown]
# # **Processing the Unpublished Sequences**
# ### **To retrive unpublished data from [BOLD Systems](http://www.boldsystems.org/index.php/MAS_Management_UserConsole)**, first create a [BOLD systems account](http://www.boldsystems.org/index.php/MAS_Management_NewUserApp), [login](http://www.boldsystems.org/index.php/Login/page?destination=MAS_Management_UserConsole) and request data managers, to share their data sets.
# My list of shared data sets are:
# 1. [DS-KENFRUIT](http://www.boldsystems.org/index.php/MAS_Management_DataConsole?codes=DS-KENFRUIT): managed by Dr Scott E. Miller, has 1,427 records
# 2. [DS-MPALALEP](http://www.boldsystems.org/index.php/MAS_Management_DataConsole?codes=DS-MPALALEP): managed by Dr Scott E. Miller, has 2,472 records
# 3. [DS-TBILE](http://www.boldsystems.org/index.php/MAS_Management_DataConsole?codes=DS-TBILE) (Now publicly released now): managed by Dr Scott E. Miller has 90 records
#
# My list of container Projects; these contains multiple data sets within them:
# 4. [IDRCK](http://www.boldsystems.org/index.php/MAS_Management_DataConsole?codes=IDRCK): Has a number of subprojects; IDRC,HIVE, KBIR, KALG, KFISH, KPLA, ARAK and KINS. Has 2,110 sequences (COI-5P=1,704, matK=139, rbcLa=267) out of 6,016 specimen and is managed by Dr. Daniel Masiga.
# 5. [GMTAH](http://www.boldsystems.org/index.php/MAS_Management_DataConsole?codes=GMTAH),[GMTAI](http://www.boldsystems.org/index.php/MAS_Management_DataConsole?codes=GMTAI) and [GMTAJ](http://www.boldsystems.org/index.php/MAS_Management_DataConsole?codes=GMTAJ) projects. All under the Global Malaise Program and the three have a combined total of 60 Projects and 49246 Specimens.
# >1. GMTAH: Has 26 projects titled "Kenya Malaise Mpala 2014" with 25,514 specimen, 170 species and 21,742 sequences (COI-5P=21,737, 28S=4 and EF1-alpha=1)
# >2. GMTAI: Has 26 projects titled "Kenya Malaise Kinondo 2014" with 13,656 specimen, 57 species and 11,805 sequences (COI-5P=11,801, 28S=3 and EF1-alpha=1)
# >3. GMTAJ: Has 5 projects titled "Kenya Malaise Turkana 2014" with 10,076 specimen, 63 species and 5,175 sequences (COI-5P=5,175)
#
# To retrive this data, I logged into the [BOLD Systems MAS management interface](http://www.boldsystems.org/index.php/MAS_Management_UserConsole) through Chromium web browser and for each named project above: DS-KENFRUIT, DS-MPALALEP, DS-TBILE, IDRCK AND GMTAH-GMTAI-GMTAJ (Mpala_Kinondo_Turkana_Malaise_traps), downloaded the spreadsheet and the sequence files to "/co1_metaanalysis/data/input/input_data/unpublished" directory.
#
# ### **Below we proceed with processing the unpublished records**
# 1. Generate an assamblage of all the above as "unpublished.fasta".
# 2. Filter the records from order diptera "Diptera" into "unpublished_Diptera.fasta".
# 3. Unalign i.e find and replace the "-"s from the sequences.
# 4. Put together the diptera_13012021_all_data.fasta and unpublished_Diptera_dgpd.fasta into one file: diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
# 5. Remove duplicates

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/data/input/diptera_13012021/
# source ../../../code/process_all_input_files.sh
#
# #1.
# #cp ../unpublished/unpublished.fasta ./
#
# #2.
# filter_seqs #unpublished.fasta <EOF
# #3
# #Diptera
# #n
# #EOF
#
# #3.
# remove_gaps #unpublished_Diptera.fasta
# ls ./unpublished*.fasta
#
# #4.
# #cat ./diptera_13012021_all_data.fasta ./unpublished_Diptera_dgpd.fasta #>> diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
#
# #5.
# delete_repeats #diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta <<EOF
# #y
# #EOF
# ##...11226 records are repeated in diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
# ls ./
# Out:
# Input error...
# Usage: filter_seqs file1.*[file2.* file3.* ...]
# Input error...
# Usage: remove_gaps file1.*[file2.* file3.* ...]
# ./unpublished_Diptera_dgpd.fasta
# ./unpublished_Diptera_dgpd_orig.fasta
# ./unpublished_Diptera.fasta
# ./unpublished.fasta
# Input error...
# Usage: delete_repeats file1.*[file2.* file3.* ...]
# alignment
# classify.nf
# classify.sbatch
# coiclassify.sbatch
# diptera_13012021_all_data.fasta
# diptera_13012021_all_data.genbank_ids
# diptera_13012021_all_data.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_orig.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.hdrs
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.ids
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_clash_species.tsv
# ...

# %% [markdown]
# ## **Taxonomic Classification**

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/data/input/diptera_13012021/
# source ../../../code/classify.sh
# #Classification using the ILRI hpc
# #$ sbatch -w compute05 classify.sbatch
# #Alternatively
# RDPclassifyCOI #-i diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta -m 4G -l 3000
# ls
# Out:
# Input error...
# Usage: RDPclassifyCOI -i 'file1.fasta* [file2.fasta* file3.fasta* ...]' [-l <INTEGER>] [-m <INTEGERg|G|m|M>]
# alignment
# classify.nf
# classify.sbatch
# coiclassify.sbatch
# diptera_13012021_all_data.fasta
# diptera_13012021_all_data.genbank_ids
# diptera_13012021_all_data.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_orig.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.hdrs
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.ids
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_clash_species.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_clash.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_evaluation
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_families.tsv
# ...

# %% [markdown]
# ### **Evaluation of classification results**
# 1. Convertion of data
# 2. Evaluation of taxonomic classifictaion results using R
# 3. Generation of FASTA format headers

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/data/input/diptera_13012021/
# source ../../../code/classify.sh
#
# #1. Convertion of data
# RDPcoiresults2tsv #diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa
#
# #2. Evaluation of taxonomic classifictaion results using R
# RDPresults_eval #diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa.tsv
#
# #3. Generation of FASTA format headers
# RDPcoiheaders #-i diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa.tsv -l 500 -s 1
#
# #4. Substituting headers in the final FASTA file
#
# ls
# Out:
# Input error...
# Usage: RDPcoiresults2tsv file1.*[file2.* file3.* ...]
# Input error...
# Usage: RDPresults_eval file1.tsv|_taxa[file2.* file3.* ...]
# Error 1 occured on 8
# Input error...
# Usage: RDPcoiheaders -i 'file1.tsv|_taxa[file2.* file3.* ...]' [-l <INTEGER>] [-s <percentage decimals>]
# Error 1 occured on 11
# alignment
# classify.nf
# classify.sbatch
# coiclassify.sbatch
# diptera_13012021_all_data.fasta
# diptera_13012021_all_data.genbank_ids
# diptera_13012021_all_data.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_orig.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.hdrs
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.ids
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_clash_species.tsv
# ...

# %% [markdown]
# ### Processing the Final FASTA file before Multiple Sequence Alignment.
# 1. Substituting headers in the final FASTA file
# 2. Subsetting the file by sequence length

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/data/input/diptera_13012021/
# source ../../../code/process_all_input_files.sh
# substitute_hdrs #-i diptera_all.fasta -h diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_l-500-Sc-1_headers
# #Sub_setting by Seq. length
# subset_seqs #diptera_all.fasta
# mkdir alignment
# mv #diptera_all_* ./alignment/ && cp diptera_all.fasta ./alignment/
# ls ./
# ls ./alignment/
# Out:
# Input error...
# 	Usage: substitute_hdrs -i 'file1.fasta* [file2.fasta* file3.fasta* ...]' [-h <headers>]
# Input error...
# Usage: subset_seqs file1.*[file2.* file3.* ...]
# alignment
# classify.nf
# classify.sbatch
# coiclassify.sbatch
# diptera_13012021_all_data.fasta
# diptera_13012021_all_data.genbank_ids
# diptera_13012021_all_data.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_orig.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.fasta
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.hdrs
# diptera_13012021_all_data_unpublished_Diptera_dgpd_subtree.ids
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_clash_species.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_clash.tsv
# diptera_13012021_all_data_unpublished_Diptera_dgpd_taxa_evaluation
# ...

# %% [markdown]
# ### Pre-MSA Processing, Multiple Sequence Alignment (MSA) and Post_MSA Processing.
# 1. Subsetting large FASTA files: diptera_all_500to700_data-650to660.fasta (67954 Sequences)
# 2. Alignment using PASTA
# 3. Visualise the alignments in seaview, identify poorly aligned files, subset the poorly aligned files
# 4. Refining all alignments using MUSCLE (`- refine` option)
# 5. Visualise the alignments in seaview and edit the alignments manually where necessary
# 6. Merge all alignment files using MUSCLE (`-profile` option)

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/data/input/diptera_13012021/alignment/
# source ../../../code/align.sh
#
# ##1. Subsetting diptera_all_500to700_data-650to660.fasta
# #head -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_1-5000.fasta
# #head -n 10000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_5000-10000.fasta
# #head -n 15000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_10000-15000.fasta
# #head -n 20000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_15000-20000.fasta
# #head -n 25000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_20000-25000.fasta
# #head -n 30000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_25000-30000.fasta
# #head -n 35000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_30000-35000.fasta
# #head -n 40000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_35000-40000.fasta
# #head -n 45000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_40000-45000.fasta
# #head -n 50000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_45000-50000.fasta
# #head -n 55000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_50000-55000.fasta
# #head -n 60000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_55000-60000.fasta
# #head -n 65000 diptera_all_650to660.fasta | tail -n 5000 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_60000-65000.fasta
# #tail -n 2954 diptera_all_650to660.fasta > diptera_all_500to700_data-650to660_65000-67954.fasta
# mv diptera_all_500to700_data-650to660.fasta All_diptera_all_500to700_data-650to660.fasta
#
# ##2. Alignment using PASTA
# #pasta_aln /home/gkibet/bioinformatics/github/co1_metaanalysis/data/input/diptera_13012021/alignment/diptera_all_*.fasta <<EOF
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #1
# #16
# #EOF
#
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/data/output/alignment/pasta_output/aligned/diptera_13012021/
# ##3. Of all MSA outputs diptera_all_500to700_data-650to660_50000-55000.aln had a poor alignment.
# #it was devided into 1000 sequence files and refined using MUSCLE:
# #head -n 2000 diptera_all_500to700_data-650to660_50000-55000.aln > diptera_all_500to700_data-650to660_50000-51000.aln
# #head -n 4000 diptera_all_500to700_data-650to660_50000-55000.aln | tail -n 2000 > diptera_all_500to700_data-650to660_51000-52000.aln
# #head -n 6000 diptera_all_500to700_data-650to660_50000-55000.aln | tail -n 2000 > diptera_all_500to700_data-650to660_52000-53000.aln
# #head -n 8000 diptera_all_500to700_data-650to660_50000-55000.aln | tail -n 2000 > diptera_all_500to700_data-650to660_53000-54000.aln
# #head -n 10000 diptera_all_500to700_data-650to660_50000-55000.aln | tail -n 2000 > diptera_all_500to700_data-650to660_54000-55000.aln
# muscle_refine #diptera_all_*000.aln
# ls diptera_all_*000.aln diptera_all_*000_rfnd.afa
# Out:
# diptera_all_500to700_data-650to660_10000-15000.aln
# diptera_all_500to700_data-650to660_10000-15000_rfnd.afa
# diptera_all_500to700_data-650to660_10000-15000_rfnd_diptera_all_500to700_data-650to660_15000-20000_rfnd.afa
# diptera_all_500to700_data-650to660_10000-20000_rfnd.afa
# diptera_all_500to700_data-650to660_1-10000_rfnd.afa
# diptera_all_500to700_data-650to660_15000-20000.aln
# diptera_all_500to700_data-650to660_15000-20000_rfnd.afa
# diptera_all_500to700_data-650to660_1-5000.aln
# diptera_all_500to700_data-650to660_1-5000_rfnd.afa
# diptera_all_500to700_data-650to660_1-5000_rfnd_diptera_all_500to700_data-650to660_5000-10000_rfnd.afa
# diptera_all_500to700_data-650to660_20000-25000.aln
# diptera_all_500to700_data-650to660_20000-25000_rfnd.afa
# diptera_all_500to700_data-650to660_20000-25000_rfnd_diptera_all_500to700_data-650to660_25000-30000_rfnd.afa
# diptera_all_500to700_data-650to660_20000-30000_rfnd.afa
# diptera_all_500to700_data-650to660_25000-30000.aln
# ...

# %% [markdown]
# 6. Merge all alignment files using MUSCLE (`-profile` option)

# %%
# %%bash
# cd /home/kibet/bioinformatics/github/co1_metaanalysis/data/output/alignment/pasta_output/aligned/diptera_13012021/
# source ../../../code/align.sh
# ##Edited the alignments in Seaview.
# ##Merge all alignment files
# muscle_p2p #diptera_all_500to700_data-650to660_50000-51000_rfnd.afa diptera_all_500to700_data-650to660_51000-52000_rfnd.afa
# cp diptera_all_500to700_data-650to660_50000-51000_rfnd_diptera_all_500to700_data-650to660_51000-52000_rfnd.afa diptera_all_500to700_data-650to660_50000-52000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_52000-53000_rfnd.afa diptera_all_500to700_data-650to660_53000-54000_rfnd.afa
# cp diptera_all_500to700_data-650to660_52000-53000_rfnd_diptera_all_500to700_data-650to660_53000-54000_rfnd.afa diptera_all_500to700_data-650to660_52000-54000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_50000-52000_rfnd.afa diptera_all_500to700_data-650to660_52000-54000_rfnd.afa
# cp diptera_all_500to700_data-650to660_50000-52000_rfnd_diptera_all_500to700_data-650to660_52000-54000_rfnd.afa diptera_all_500to700_data-650to660_50000-54000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_50000-54000_rfnd.afa diptera_all_500to700_data-650to660_54000-55000_rfnd.afa
# cp diptera_all_500to700_data-650to660_50000-54000_rfnd_diptera_all_500to700_data-650to660_54000-55000_rfnd.afa diptera_all_500to700_data-650to660_50000-55000_rfnd_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_1-5000_rfnd.afa diptera_all_500to700_data-650to660_5000-10000_rfnd.afa
# cp diptera_all_500to700_data-650to660_1-5000_rfnd_diptera_all_500to700_data-650to660_5000-10000_rfnd.afa diptera_all_500to700_data-650to660_1-10000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_10000-15000_rfnd.afa diptera_all_500to700_data-650to660_15000-20000_rfnd.afa
# cp diptera_all_500to700_data-650to660_10000-15000_rfnd_diptera_all_500to700_data-650to660_15000-20000_rfnd.afa diptera_all_500to700_data-650to660_10000-20000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_20000-25000_rfnd.afa diptera_all_500to700_data-650to660_25000-30000_rfnd.afa
# cp diptera_all_500to700_data-650to660_20000-25000_rfnd_diptera_all_500to700_data-650to660_25000-30000_rfnd.afa diptera_all_500to700_data-650to660_20000-30000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_30000-35000_rfnd.afa diptera_all_500to700_data-650to660_35000-40000_rfnd.afa
# cp diptera_all_500to700_data-650to660_30000-35000_rfnd_diptera_all_500to700_data-650to660_35000-40000_rfnd.afa diptera_all_500to700_data-650to660_30000-40000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_40000-45000_rfnd.afa diptera_all_500to700_data-650to660_45000-50000_rfnd.afa
# cp diptera_all_500to700_data-650to660_40000-45000_rfnd_diptera_all_500to700_data-650to660_45000-50000_rfnd.afa diptera_all_500to700_data-650to660_40000-50000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_50000-55000_rfnd_rfnd.afa diptera_all_500to700_data-650to660_55000-60000_rfnd.afa
# cp diptera_all_500to700_data-650to660_50000-55000_rfnd_rfnd_diptera_all_500to700_data-650to660_55000-60000_rfnd.afa diptera_all_500to700_data-650to660_50000-60000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_60000-65000_rfnd.afa diptera_all_500to700_data-650to660_65000-67954.aln
# cp diptera_all_500to700_data-650to660_60000-65000_rfnd_diptera_all_500to700_data-650to660_65000-67954.afa diptera_all_500to700_data-650to660_60000-67954_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_1-10000_rfnd.afa diptera_all_500to700_data-650to660_10000-20000_rfnd.afa
# cp diptera_all_500to700_data-650to660_1-10000_rfnd_diptera_all_500to700_data-650to660_10000-20000_rfnd.afa diptera_all_500to700_data-650to660_1-20000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_20000-30000_rfnd.afa diptera_all_500to700_data-650to660_30000-40000_rfnd.afa
# cp diptera_all_500to700_data-650to660_20000-30000_rfnd_diptera_all_500to700_data-650to660_30000-40000_rfnd.afa diptera_all_500to700_data-650to660_20000-40000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_40000-50000_rfnd.afa diptera_all_500to700_data-650to660_50000-60000_rfnd.afa
# cp diptera_all_500to700_data-650to660_40000-50000_rfnd_diptera_all_500to700_data-650to660_50000-60000_rfnd.afa  diptera_all_500to700_data-650to660_40000-60000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_1-20000_rfnd.afa diptera_all_500to700_data-650to660_20000-40000_rfnd.afa
# cp diptera_all_500to700_data-650to660_1-20000_rfnd_diptera_all_500to700_data-650to660_20000-40000_rfnd.afa diptera_all_500to700_data-650to660_1-40000_rfnd.afa
# muscle_p2p #diptera_all_500to700_data-650to660_40000-60000_rfnd.afa diptera_all_500to700_data-650to660_60000-67954_rfnd.afa
# cp diptera_all_500to700_data-650to660_40000-60000_rfnd_diptera_all_500to700_data-650to660_60000-67954_rfnd.afa diptera_all_500to700_data-650to660_40000-67954_rfnd.afa
#
# ls *_rfnd.afa
# Out:
# diptera_all_500to700_data-650to660_10000-15000_rfnd.afa
# diptera_all_500to700_data-650to660_15000-20000_rfnd.afa
# diptera_all_500to700_data-650to660_1-5000_rfnd.afa
# diptera_all_500to700_data-650to660_20000-25000_rfnd.afa
# diptera_all_500to700_data-650to660_25000-30000_rfnd.afa
# diptera_all_500to700_data-650to660_30000-35000_rfnd.afa
# diptera_all_500to700_data-650to660_35000-40000_rfnd.afa
# diptera_all_500to700_data-650to660_40000-45000_rfnd.afa
# diptera_all_500to700_data-650to660_45000-50000_rfnd.afa
# diptera_all_500to700_data-650to660_50000-51000_rfnd.afa
# diptera_all_500to700_data-650to660_50000-51000_rfnd_diptera_all_500to700_data-650to660_51000-52000_rfnd.afa
# diptera_all_500to700_data-650to660_50000-52000_rfnd.afa
# diptera_all_500to700_data-650to660_50000-52000_rfnd_diptera_all_500to700_data-650to660_52000-54000_rfnd.afa
# diptera_all_500to700_data-650to660_50000-54000_rfnd.afa
# ...
